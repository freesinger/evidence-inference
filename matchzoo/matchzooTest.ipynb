# %%
import torch
import os
import pandas as pd
import matchzoo as mz
import numpy as np
from sklearn.model_selection import train_test_split

# %%
TYPE = 'classification'

classification_task = mz.tasks.Classification(num_classes=3)
classification_task.metrics = ['acc']
print(classification_task.num_classes)
print(classification_task.output_shape)
print(classification_task.output_dtype)
print(classification_task)
# Out:
# 3
# (3,)
# <class 'int'>
# Classification Task with 3 classes

# %% [markdown]
# # Data Pack Sample

# %%
# pack
df = pd.DataFrame(data={'text_left': list('ABBCD'),
                       'text_right': list('aacbd'),
                       'label': [-1, 1, 0, 0, 1]})
mz.pack(df, task=TYPE).frame()
# Out:
#   id_left text_left id_right text_right  label
# 0     L-0         A      R-0          a     -1
# 1     L-1         B      R-0          a      1
# 2     L-1         B      R-1          c      0
# 3     L-2         C      R-2          b      0
# 4     L-3         D      R-3          d      1

# %%
# data_pack
left = [
    ['artid1', 'A1'],
    ['artid2', 'A2'],
    ['artid3', 'A3']
]
right = [
    ['hypoid1', 'prompt1'],
    ['hypoid2', 'prompt2'],
    ['hypoid3', 'prompt3']
]
relation = [
    ['artid1', 'hypoid1', -1],
    ['artid1', 'hypoid3', 1],
    ['artid2', 'hypoid2', 0],
    ['artid3', 'hypoid3', 1]
]

relation_df = pd.DataFrame(relation)
# relation_df
left = pd.DataFrame(left)
right = pd.DataFrame(right)
dp = mz.DataPack(
    relation=relation_df,
    left=left,
    right=right
)
# print(len(dp))
# print(type(dp.frame))
# frame_slice = dp.frame[0:5]
# type(frame_slice)
# list(frame_slice.columns)
# full_frame = dp.frame()

# %%
data_pack = mz.datasets.toy.load_data(stage='train')
type(data_pack)
# Out:
# matchzoo.data_pack.data_pack.DataPack

# %% [markdown]
# # Prepare input data

# %%
annot = pd.read_csv('../annotations/annotations_merged.csv')
print(annot.dtypes)
annot.sort_values('PMCID').head(10)
# Out:
# UserID              int64
# PromptID            int64
# PMCID               int64
# Valid Label          bool
# Valid Reasoning      bool
# Label              object
# Annotations        object
# Label Code          int64
# In Abstract          bool
# Evidence Start      int64
# Evidence End        int64
# dtype: object
#        UserID  PromptID   PMCID  Valid Label  Valid Reasoning  \
# 13994       0      7902   60007         True             True
# 14000       3      7904   60007         True             True
# 12483       0      7905   60007         True             True
# 12484       1      7905   60007         True             True
# 13999       0      7904   60007         True             True
# 13998       3      7903   60007         True             True
# 13997       0      7903   60007         True             True
# 13995       3      7902   60007         True             True
# 2855        0      1806  111193         True             True
# 2334        0      1808  111193         True             True
#
#                            Label  \
# 13994    significantly increased
# 14000  no significant difference
# 12483    significantly decreased
# 12484    significantly decreased
# 13999  no significant difference
# 13998  no significant difference
# 13997  no significant difference
# 13995    significantly increased
# 2855   no significant difference
# 2334   no significant difference
#
#                                              Annotations  Label Code  \
# 13994  Mivacurium 250 μg/kg produced a maximal T bloc...           1
# 14000               Heart rate was similar between doses           0
# 12483  while both AUC-SBP and AUC-DBP were significan...          -1
# 12484  In relation to the cardiovascular response, th...          -1
# 13999  In relation to the cardiovascular response, th...           0
# 13998  Spontaneous recovery times were similar in bot...           0
# 13997  The times to OA and to spontaneous recovery of...           0
# 13995  Mivacurium 250 μg/kg produced a maximal T bloc...           1
# 2855   The amount of blood transfusion was identical ...           0
# 2334   There was no difference in time spent in hospi...           0
#
#        In Abstract  Evidence Start  Evidence End
# 13994         True            1280          1395
# 14000         True            1452          1488
# 12483        False           16737         16836
# 12484        False           16641         16836
# 13999        False           16641         16736
# 13998         True            1396          1450
# 13997        False           14755         15079
# 13995         True            1280          1395
# 2855          True            1418          1578
# 2334         False           14701         14770

# %%
"""Process txt file for Articles input"""
TXT_PATH = '../annotations/txt_files/'
TAR_PATH = '../annotations/processed_txt_files/'
look_up = {}

if not os.path.exists(TAR_PATH):
    os.mkdir(TAR_PATH)
# else: os.removedirs(TAR_PATH)
for file in os.listdir(TXT_PATH):
    fname = file[3:]
    look_up[int(file[3:-4])] = fname
    with open(TXT_PATH+file, 'r', encoding='utf-8') as f, open(TAR_PATH+fname, 'w', encoding='utf-8') as t:
        for line in f.readlines():
            t.write(line.strip())

# %%
"""Articles Map"""
left_articles = []
for file in os.listdir(TAR_PATH):
    with open(TAR_PATH+file, 'r', encoding='utf-8') as f:
        left_articles.append([int(file[:-4]), f.readlines()[0]])
# print(left_articles[0:5])

"""Prompts Map"""
right_prompts = [list(pair) for pair in zip(annot['PromptID'].values, annot['Annotations'].values)]
print(right_prompts[0:5])

"""Articles <-> Prompts Map"""
article_prompt_relations = [list(triplet) for triplet in zip(annot['PMCID'].values, 
                                                             annot['PromptID'].values, 
                                                             annot['Label Code'].values)]
print(article_prompt_relations[0:5])

"""Create Data-pack"""
left = pd.DataFrame(left_articles, columns=['id_left', 'text_left'])
right = pd.DataFrame(right_prompts, columns=['id_right', 'text_right'])
relation = pd.DataFrame(article_prompt_relations, columns=['id_left', 'id_right', 'label'])
dp = mz.DataPack(
    relation = relation,
    left = left,
    right = right
)

# print(left)
# print(len(dp))
# print(type(dp.frame))
# frame = dp.frame
# print(list(frame().columns))
# # frame_slice = dp.frame[0:5]
# # type(frame_slice)
# # list(frame_slice.columns)
# full_frame = dp.frame()
# Out:
# [[213, 'IL-6r (ng/ml)\t\t\t\t\t\t\t Group A\t43.6 (1.7–125.0)\t\t47.4 (0.7–109.5)\t56.2 (25.2–226.3)\t\t\t0.949† Group B\t40.7 (15.6–94.6)\t\t42.4 (22.2–100.5)\t50.2 (13.2–104.9)\t\t\t0.861†\tp = 0.607*\t\tp = 0.914*\tp = 0.304*'], [213, 'There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups.'], [213, 'There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups'], [213, 'There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups'], [98, 'After two weeks of treatment, the reduction in ulcer area was doubled in the HBOT group (P = 0.037)']]
# [[2206488, 213, 0], [2206488, 213, 0], [2206488, 213, 0], [2206488, 213, 0], [2858204, 98, 1]]

# %%
""" Read article by name """
def read_article(id) -> str:
    with open(TAR_PATH+look_up[id], 'r', encoding='utf-8') as f:
        return f.readlines()[0]

text_left = [read_article(id) for id in annot['PMCID']]
# print(text_left[0:5])

# %%
df = pd.DataFrame(data={
    'id_left': annot['PMCID'].astype(str),
    'text_left': text_left,
    'id_right': annot['PromptID'].astype(str),
    'text_right': annot['Annotations'],
    'label': annot['Label Code']
})
print(df.dtypes)

""" Split data pack into train/valid """
train, valid = train_test_split(df, test_size=0.2)
train_pack = mz.pack(train, task=TYPE)
valid_pack = mz.pack(valid, task=TYPE)
train_pack.frame().head(10) # DataFrame
# Out:
# id_left       object
# text_left     object
# id_right      object
# text_right    object
# label          int64
# dtype: object
#    id_left                                          text_left id_right  \
# 0  2720945  TITLE: Concomitant therapy with Cineole (Eucal...      454
# 1  4274965  TITLE: Adult age differences in prospective me...     7944
# 2  2781775  TITLE: Evaluating Complementary Therapies for ...    10996
# 3  1839864  TITLE: Improving Death Certificate Completion:...     4594
# 4  1693558  TITLE: Low-frequency vibratory exercise reduce...    10710
# 5  4079189  TITLE: Effect of myrtle fruit syrup on abnorma...     4761
# 6  3800406  TITLE: Effect of hydrogen peroxide mouthwash a...     8795
# 7  3781502  TITLE: Efficacy and Safety of Lixisenatide Onc...     5190
# 8  5672307  TITLE: Effects of matrix on plasma levels of E...     9852
# 9  4716419  TITLE: A multicentre, randomised controlled st...     1330
#
#                                           text_right  label
# 0  Dyspnea during exercise $\t2.0 ± 0.6\t1.8 ± 0....      0
# 1  Moreover for the overall ANOVA, there was no s...      0
# 2  three of the variables [veterinary-assessed mo...     -1
# 3  The death certificate score improved significa...      1
# 4  The WBV group reduced more the BMI than the Wa...     -1
# 5  The mean number of bleeding days significantly...     -1
# 6  fter the end of 3 weeks also, the plaque score...      0
# 7  Mean (±SD) HbA1c decreased from 7.97% (±0.82) ...      0
# 8  CCx (median = 2·471) AUC0–24 h was significant...     -1
# 9  At the 12th month, both arms were comparable i...      0

# %%
dp = mz.pack(df, task=TYPE)
print(type(dp.frame))
frame_slice = dp.frame[0:5]
print(list(frame_slice.columns))
full_frame = dp.frame()
len(full_frame) == len(dp)
# Out:
# <class 'matchzoo.data_pack.data_pack.DataPack.FrameView'>
# ['id_left', 'text_left', 'id_right', 'text_right', 'label']
# True

# %% [markdown]
# # Model and Train

# %%
preprocessor = mz.models.ArcI.get_default_preprocessor()
train_processed = preprocessor.fit_transform(train_pack)
valid_processed = preprocessor.transform(valid_pack)
# Out:
# Processing text_left with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 2400/2400 [01:37<00:00, 24.70it/s]
# Processing text_right with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 9469/9469 [00:03<00:00, 2869.95it/s]
# Processing text_right with append: 100%|██████████| 9469/9469 [00:00<00:00, 634175.34it/s]
# Building FrequencyFilter from a datapack.: 100%|██████████| 9469/9469 [00:00<00:00, 90028.23it/s]
# Processing text_right with transform: 100%|██████████| 9469/9469 [00:00<00:00, 66741.95it/s]
# Processing text_left with extend: 100%|██████████| 2400/2400 [00:00<00:00, 16246.73it/s]
# Processing text_right with extend: 100%|██████████| 9469/9469 [00:00<00:00, 503669.67it/s]
# Building Vocabulary from a datapack.: 100%|██████████| 8836909/8836909 [00:03<00:00, 2657008.98it/s]
# Processing text_left with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 2400/2400 [01:33<00:00, 25.55it/s]
# Processing text_right with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 9469/9469 [00:02<00:00, 3226.60it/s]
# Processing text_right with transform: 100%|██████████| 9469/9469 [00:00<00:00, 110441.18it/s]
# Processing text_left with transform: 100%|██████████| 2400/2400 [00:03<00:00, 640.32it/s]
# Processing text_right with transform: 100%|██████████| 9469/9469 [00:00<00:00, 42977.56it/s]
# Processing length_left with len: 100%|██████████| 2400/2400 [00:00<00:00, 594690.71it/s]
# Processing length_right with len: 100%|██████████| 9469/9469 [00:00<00:00, 608905.55it/s]
# Processing text_left with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 1862/1862 [01:05<00:00, 28.29it/s]
# Processing text_right with chain_transform of Tokenize => Lowercase => PuncRemoval: 100%|██████████| 3501/3501 [00:01<00:00, 1984.58it/s]
# Processing text_right with transform: 100%|██████████| 3501/3501 [00:00<00:00, 125862.55it/s]
# Processing text_left with transform: 100%|██████████| 1862/1862 [00:02<00:00, 786.28it/s]
# Processing text_right with transform: 100%|██████████| 3501/3501 [00:00<00:00, 24136.73it/s]
# Processing length_left with len: 100%|██████████| 1862/1862 [00:00<00:00, 427442.07it/s]
# Processing length_right with len: 100%|██████████| 3501/3501 [00:00<00:00, 479001.12it/s]

# %%
trainset = mz.dataloader.Dataset(
    data_pack=train_processed,
    mode='pair',
    num_dup=1,
    num_neg=4
)
validset = mz.dataloader.Dataset(
    data_pack=valid_processed,
    mode='point'
)

# %%
padding_callback = mz.models.ArcI.get_default_padding_callback()

trainloader = mz.dataloader.DataLoader(
    dataset=trainset,
    stage='train',
    callback=padding_callback
)
validloader = mz.dataloader.DataLoader(
    dataset=validset,
    stage='dev',
    callback=padding_callback
)

# %%
model = mz.models.ArcI()
model.params['task'] = classification_task
model.params['embedding_output_dim'] = 100
model.params['embedding_input_dim'] = preprocessor.context['embedding_input_dim']
model.guess_and_fill_missing_params()
model.build()

# %%
optimizer = torch.optim.Adam(model.parameters())

trainer = mz.trainers.Trainer(
    model=model,
    optimizer=optimizer,
    trainloader=trainloader,
    validloader=validloader,
    epochs=10
)

trainer.run()
# Out:
# HBox(children=(IntProgress(value=0, max=210), HTML(value='')))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-10309d6c3d2d> in <module>
#       9 )
#      10
# ---> 11 trainer.run()
#
# ~/anaconda3/lib/python3.6/site-packages/matchzoo/trainers/trainer.py in run(self)
#     225         for epoch in range(self._start_epoch, self._epochs + 1):
#     226             self._epoch = epoch
# --> 227             self._run_epoch()
#     228             self._run_scheduler()
#     229             if self._early_stopping.should_stop_early:
#
# ~/anaconda3/lib/python3.6/site-packages/matchzoo/trainers/trainer.py in _run_epoch(self)
#     253                 # Caculate all losses and sum them up
#     254                 loss = torch.sum(
# --> 255                     *[c(outputs, target) for c in self._criterions]
#     256                 )
#     257                 self._backward(loss)
#
# ~/anaconda3/lib/python3.6/site-packages/matchzoo/trainers/trainer.py in <listcomp>(.0)
#     253                 # Caculate all losses and sum them up
#     254                 loss = torch.sum(
# --> 255                     *[c(outputs, target) for c in self._criterions]
#     256                 )
#     257                 self._backward(loss)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     914     def forward(self, input, target):
#     915         return F.cross_entropy(input, target, weight=self.weight,
# --> 916                                ignore_index=self.ignore_index, reduction=self.reduction)
#     917
#     918
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2007     if size_average is not None or reduce is not None:
#    2008         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2009     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    2010
#    2011
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1836                          .format(input.size(0), target.size(0)))
#    1837     if dim == 2:
# -> 1838         ret = torch._C._nn.nll_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    1839     elif dim == 4:
#    1840         ret = torch._C._nn.nll_loss2d(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#
# RuntimeError: Assertion `cur_target >= 0 && cur_target < n_classes' failed.  at /Users/distiller/project/conda/conda-bld/pytorch_1573049308345/work/aten/src/THNN/generic/ClassNLLCriterion.c:97

# %%
pwd
