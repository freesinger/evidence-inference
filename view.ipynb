# %%
import numpy as np
import pandas as pd
import os

# %%
annot = pd.read_csv('./annotations/annotations_merged.csv')
annot.head(10)
# Out:
#    UserID  PromptID    PMCID  Valid Label  Valid Reasoning  \
# 0       0       213  2206488         True             True
# 1       1       213  2206488         True             True
# 2       3       213  2206488         True             True
# 3       2       213  2206488         True             True
# 4       0        98  2858204         True             True
# 5       1        98  2858204         True             True
# 6       3        98  2858204         True             True
# 7       2        98  2858204         True             True
# 8       0       150  2871176         True             True
# 9       3       150  2871176         True             True
#
#                        Label  \
# 0  no significant difference
# 1  no significant difference
# 2  no significant difference
# 3  no significant difference
# 4    significantly increased
# 5    significantly increased
# 6    significantly increased
# 7    significantly increased
# 8    significantly increased
# 9    significantly increased
#
#                                          Annotations  Label Code  In Abstract  \
# 0  IL-6r (ng/ml)\t\t\t\t\t\t\t Group A\t43.6 (1.7...           0        False
# 1  There was no significant difference in IL 6, I...           0         True
# 2  There was no significant difference in IL 6, I...           0         True
# 3  There was no significant difference in IL 6, I...           0         True
# 4  After two weeks of treatment, the reduction in...           1         True
# 5  After two weeks of treatment, the reduction in...           1         True
# 6  After two weeks of treatment, the reduction in...           1         True
# 7  After two weeks of treatment, the reduction in...           1         True
# 8  The proportion of subjects experiencing minor ...           1        False
# 9  Incidence was higher with liraglutide 1.2 mg (...           1        False
#
#    Evidence Start  Evidence End
# 0              -1            -1
# 1            1612          1708
# 2            1612          1707
# 3            1612          1707
# 4           18239         18338
# 5           18239         18339
# 6           18239         18339
# 7           18239         18339
# 8           25524         26184
# 9           25964         26073

# %%
 for i in range(10):
    print(i, annot['Annotations'][i])
# Out:
# 0 IL-6r (ng/ml)							 Group A	43.6 (1.7–125.0)		47.4 (0.7–109.5)	56.2 (25.2–226.3)			0.949† Group B	40.7 (15.6–94.6)		42.4 (22.2–100.5)	50.2 (13.2–104.9)			0.861†	p = 0.607*		p = 0.914*	p = 0.304*
# 1 There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups.
# 2 There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups
# 3 There was no significant difference in IL 6, IL-6r and C-reactive protein values between groups
# 4 After two weeks of treatment, the reduction in ulcer area was doubled in the HBOT group (P = 0.037)
# 5 After two weeks of treatment, the reduction in ulcer area was doubled in the HBOT group (P = 0.037).
# 6 After two weeks of treatment, the reduction in ulcer area was doubled in the HBOT group (P = 0.037).
# 7 After two weeks of treatment, the reduction in ulcer area was doubled in the HBOT group (P = 0.037).
# 8 The proportion of subjects experiencing minor hypoglycaemia during the trial was lowest with placebo (i.e. glimepiride monotherapy 2.6%; 0.17 events/subject-year), comparable with liraglutide 0.6 mg (5.2%, 0.17 events/subject-year) and rosiglitazone (4.3%, 0.12 events/subject-year) groups and similar between the liraglutide 1.2 mg (9.2%, 0.51 events/subject-year) and liraglutide 1.8 mg (8.1%, 0.47 events/subject-year) treatment groups. Incidence was higher with liraglutide 1.2 mg (P = 0.0024) and 1.8 mg (P = 0.0065) compared with rosiglitazone and liraglutide 1.2 mg compared with placebo (P = 0.048), occurring in the setting of lower mean HbA1c values.
# 9 Incidence was higher with liraglutide 1.2 mg (P = 0.0024) and 1.8 mg (P = 0.0065) compared with rosiglitazone

# %%
annot.tail(10)
# Out:
#        UserID  PromptID    PMCID  Valid Label  Valid Reasoning  \
# 19706       0      5223  5856907         True             True
# 19707       0      5691  4329409         True             True
# 19708       0      5909  3327628         True             True
# 19709       3      6126  5927490         True             True
# 19710       0      7511  4701161         True             True
# 19711       1      8164  2954378         True             True
# 19712       0      8254  3511173         True             True
# 19713       0      8543  4065461         True             True
# 19714       1      8771  4280732         True             True
# 19715       0     10011  5954168         True             True
#
#                            Label  \
# 19706    significantly increased
# 19707    significantly increased
# 19708    significantly decreased
# 19709  no significant difference
# 19710    significantly increased
# 19711    significantly increased
# 19712    significantly decreased
# 19713    significantly increased
# 19714    significantly increased
# 19715    significantly increased
#
#                                              Annotations  Label Code  \
# 19706  5. Felt uncomfortable and I did not participat...           1
# 19707  CZP 200 mg every 2 weeks and 400 mg every 4 we...           1
# 19708               Cardiology\t12.7\t9.9\t15.5\t< .0001          -1
# 19709  the Standard group showed increased MMP9 level...           0
# 19710  Based on cycle threshold numbers, the relative...           1
# 19711  he variability of the median day-to-day forced...           1
# 19712  The PEG-only group was better in terms of tole...          -1
# 19713  Treatment with dexamethasone + epinephrine res...           1
# 19714  Analysis of delivery method showed that in mot...           1
# 19715  The death rate was higher in the nonbiopsied p...           1
#
#        In Abstract  Evidence Start  Evidence End
# 19706        False           20293         20405
# 19707         True            1896          2075
# 19708        False              -1            -1
# 19709         True            1244          1346
# 19710        False           24796         25065
# 19711         True             766          1128
# 19712        False           13570         13692
# 19713         True            1606          1753
# 19714         True            1444          1629
# 19715        False           17199         17353

# %%
print("Annotations len: ", len(annot))
print("Unique PromptID numbers: ", len(annot['PromptID'].unique()))
# Out:
# Annotations len:  19716
# Unique PromptID numbers:  10113

# %%
prompt = pd.read_csv('./annotations/prompts_merged.csv')

# %%
prompt.head(10)
# Out:
#    PromptID    PMCID                                            Outcome  \
# 0       213  2206488                                      IL-6r (ng/ml)
# 1        98  2858204   downsizing of ucler area 2 weeks after treatment
# 2       150  2871176                   Incidence of minor hypoglycaemia
# 3       191  2517154                                Dysmenorrhea scores
# 4       113  2871176  Patients reaching HbA1c goals less than 7.0% a...
# 5        95  2944158                                    IVD dwell times
# 6       163  2708184                           Berg Balance Scale score
# 7       140  2871176                                            HOMA-IR
# 8       106  2871176                            HbA1c level at 26 weeks
# 9       169  2864284                        Parasite clearance at day 2
#
#                                         Intervention  \
# 0  dextran-70 infusion was administered at a dose...
# 1                                              HBOT
# 2              Liraglutide (1.2 mg) plus glimepiride
# 3                                         Infliximab
# 4              Liraglutide (1.8 mg) plus glimepiride
# 5                      staff inclination replacement
# 6  Body-weight supported treadmill training combi...
# 7           Liraglutide (all doses) plus glimepiride
# 8              Liraglutide (0.6 mg) plus glimepiride
# 9                     Dihydroartemisinin-piperaquine
#
#                                           Comparator
# 0              identical amounts of gelatin infusion
# 1                                            placebo
# 2                     Rosiglitazone plus glimepiride
# 3                                            Placebo
# 4                     Rosiglitazone plus glimepiride
# 5                                routine replacement
# 6  Body-weight supported treadmill training combi...
# 7                     Rosiglitazone plus glimepiride
# 8                           Placebo plus glimepiride
# 9                                        Chloroquine

# %%
prompt.dtypes
# Out:
# PromptID         int64
# PMCID            int64
# Outcome         object
# Intervention    object
# Comparator      object
# dtype: object

# %%
print("Prompt numbers: ", len(prompt))
print("Unique PromptID numbers: ", len(prompt['PromptID'].unique()))
# Out:
# Prompt numbers:  10137
# Unique PromptID numbers:  10137
